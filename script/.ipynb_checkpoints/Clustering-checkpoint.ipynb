# %%
# imports
from __future__ import print_function
from time import time
import numpy as np
import pandas as pd
import pickle 
import random
import csv
import timeit
import os
import spacy
import string 

# Sklearn
from pprint import pprint
from sklearn.preprocessing import LabelEncoder
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# NLP libraries
import re
import matplotlib.pyplot as plt

# xml
from bs4 import BeautifulSoup

# %%
def generate_corpus(filename):
    corpus = []
    soup = BeautifulSoup(open(filename, "r"), "lxml")
    for r in soup.find_all('review'):
        doc = ""
        for sentence in r.find_all('text'):
            doc += " " + sentence.text
        corpus.append(doc)
    return corpus

# %%
def w2v(word, model, dim, oov_model=None):
    try:
        return model.loc[word].values
    except:
        if oov_model is not None:
            try:
                return oov_model.loc[word].values
            except:
                return np.zeros((dim,))
        return np.zeros((dim,))

# %%
#TODO: replace split with tokenize

def get_target_embeddings(filename, glove_model, domain_model, use_fastText=False):
    punctuation_string = "".join(string.punctuation)
    targets = []
    categories = []
    
    words = []
    embeddings = []
    dom_embeddings = []
    
    soup = BeautifulSoup(open(filename, "r"), "lxml")
    i = 0
    for r in soup.find_all('opinion'):
        targets.append(r.get('target'))
        categories.append(r.get('category')[:r.get('category').index("#")])
    
    target_to_cat = dict(zip(targets, categories))
    targets = set(targets)
    categories = []
    
    #let us handle OOV words.
    oov_model = None
    if use_fastText:
        oov_words = []
        for t in targets:
            if len(t.split()) > 1:
                for w in t.split():
                    try:
                        emb = domain_model.loc[w.strip(punctuation_string)]
                    except:
                        oov_words.append(w)
            else:
                try:
                    emb = domain_model.loc[t.strip(punctuation_string)]
                except:
                    oov_words.append(t)
        oov_words = set(oov_words)
        
        with open("./oov_words.txt", "w") as file:
            for w in oov_words:
                file.write(w + "\n")
        
        start_time = timeit.default_timer()
        
        bashCommand = "./fastText-0.2.0/fasttext print-word-vectors ./data/embedding/restaurant_emb.vec.bin < ./oov_words.txt > ./oov.vec"
        os.system(bashCommand)
        
        elapsed = timeit.default_timer() - start_time
        print("Word vectors written, it took " + str(elapsed) + " seconds")
        oov_model = pd.read_csv("./oov.vec", sep=" ", header=None, index_col=0, skiprows=1)
        oov_model = oov_model.drop(labels=101, axis=1)
    
    for t in targets:
        if len(t.split()) > 1:
            emb = np.max([w2v(w.strip(punctuation_string), glove_model, 300) for w in t.split()], axis=0)
            dom_emb = np.max([w2v(w.strip(punctuation_string), domain_model, 100, oov_model) for w in t.split()], axis=0)
        else:
            emb = w2v(t.strip(punctuation_string), glove_model, 300)
            dom_emb = w2v(t.strip(punctuation_string), domain_model, 100, oov_model)
        embeddings.append(emb)
        dom_embeddings.append(dom_emb)
        words.append(t)
        categories.append(target_to_cat[t])        
        
        i+=1
        print(str(i) + str(emb.shape) + " " + str(dom_emb.shape))
    
    
    #normalize:
    embeddings = [e/np.linalg.norm(e) if np.linalg.norm(e) != 0 else e for e in embeddings]
    dom_embeddings = [e/np.linalg.norm(e) if np.linalg.norm(e) != 0 else e for e in dom_embeddings]
    
    le = LabelEncoder()
    return words, le.fit_transform(categories), embeddings, dom_embeddings

# %%
filename = "./data/official_data/ABSA16_Restaurants_Train_SB1_v2.xml"

# %%
glove_model = pd.read_csv("./data/embedding/gen.vec", sep=" ", index_col=0, header=None, quoting=csv.QUOTE_NONE)

# %%
domain_model = pd.read_csv("./data/embedding/restaurant_emb.vec", sep=" ", header=None, index_col=0, skiprows=1)
domain_model = domain_model.drop(labels=101, axis=1)

# %%
doc_set = generate_corpus(filename)

# %%
words, categories, embeddings, dom_embeddings = get_target_embeddings(filename, glove_model, domain_model, use_fastText=True)
# Out:
# Word vectors written, it took 8.619101969525218 seconds
# 1(300,) (100,)
# 2(300,) (100,)
# 3(300,) (100,)
# 4(300,) (100,)
# 5(300,) (100,)
# 6(300,) (100,)
# 7(300,) (100,)
# 8(300,) (100,)
# 9(300,) (100,)
# 10(300,) (100,)
# 11(300,) (100,)
# 12(300,) (100,)
# 13(300,) (100,)
# 14(300,) (100,)
# 15(300,) (100,)
# 16(300,) (100,)
# 17(300,) (100,)
# 18(300,) (100,)
# 19(300,) (100,)
# 20(300,) (100,)
# 21(300,) (100,)
# 22(300,) (100,)
# 23(300,) (100,)
# 24(300,) (100,)
# 25(300,) (100,)
# 26(300,) (100,)
# 27(300,) (100,)
# 28(300,) (100,)
# 29(300,) (100,)
# 30(300,) (100,)
# 31(300,) (100,)
# 32(300,) (100,)
# 33(300,) (100,)
# 34(300,) (100,)
# 35(300,) (100,)
# 36(300,) (100,)
# 37(300,) (100,)
# 38(300,) (100,)
# 39(300,) (100,)
# 40(300,) (100,)
# 41(300,) (100,)
# 42(300,) (100,)
# 43(300,) (100,)
# 44(300,) (100,)
# 45(300,) (100,)
# 46(300,) (100,)
# 47(300,) (100,)
# 48(300,) (100,)
# 49(300,) (100,)
# 50(300,) (100,)
# 51(300,) (100,)
# 52(300,) (100,)
# 53(300,) (100,)
# 54(300,) (100,)
# 55(300,) (100,)
# 56(300,) (100,)
# 57(300,) (100,)
# 58(300,) (100,)
# 59(300,) (100,)
# 60(300,) (100,)
# 61(300,) (100,)
# 62(300,) (100,)
# 63(300,) (100,)
# 64(300,) (100,)
# 65(300,) (100,)
# 66(300,) (100,)
# 67(300,) (100,)
# 68(300,) (100,)
# 69(300,) (100,)
# 70(300,) (100,)
# 71(300,) (100,)
# 72(300,) (100,)
# 73(300,) (100,)
# 74(300,) (100,)
# 75(300,) (100,)
# 76(300,) (100,)
# 77(300,) (100,)
# 78(300,) (100,)
# 79(300,) (100,)
# 80(300,) (100,)
# 81(300,) (100,)
# 82(300,) (100,)
# 83(300,) (100,)
# 84(300,) (100,)
# 85(300,) (100,)
# 86(300,) (100,)
# 87(300,) (100,)
# 88(300,) (100,)
# 89(300,) (100,)
# 90(300,) (100,)
# 91(300,) (100,)
# 92(300,) (100,)
# 93(300,) (100,)
# 94(300,) (100,)
# 95(300,) (100,)
# 96(300,) (100,)
# 97(300,) (100,)
# 98(300,) (100,)
# 99(300,) (100,)
# 100(300,) (100,)
# 101(300,) (100,)
# 102(300,) (100,)
    pickle.dump((words, categories, embeddings, dom_embeddings), pickle_in)

# %%
concat_embeddings = [np.hstack((ge,de)) for ge,de in zip(embeddings, dom_embeddings)]

# %%
#seeds for kmeansp.mean


#food
food_seed = np.mean([concat_embeddings[words.index('bread')], concat_embeddings[words.index('burgers')], 
                     concat_embeddings[words.index('noodles')], concat_embeddings[words.index('rice')], 
                     concat_embeddings[words.index('bread')], concat_embeddings[words.index('steak')]], axis=0)

drinks_seed = np.mean([concat_embeddings[words.index('wine')], concat_embeddings[words.index('beer')], 
                     concat_embeddings[words.index('noodles')], concat_embeddings[words.index('coffee')], 
                     concat_embeddings[words.index('drinks')]], axis=0)

service_seed = np.mean([concat_embeddings[words.index('service')], concat_embeddings[words.index('staff')], 
                     concat_embeddings[words.index('crew')], concat_embeddings[words.index('hostess')], 
                     concat_embeddings[words.index('waitstaff')]], axis=0)

ambience_seed = np.mean([concat_embeddings[words.index('ambience')], concat_embeddings[words.index('decor')], 
                     concat_embeddings[words.index('seating')], concat_embeddings[words.index('atmosphere')], 
                     concat_embeddings[words.index('furnishings')]], axis=0)

misc_seed = np.mean([concat_embeddings[words.index('place')], concat_embeddings[words.index('spot')]], axis=0)

# %%
from sklearn.cluster import KMeans, DBSCAN

cluster_centers = np.asarray([food_seed, drinks_seed, service_seed, ambience_seed, misc_seed])
kmeans = KMeans(n_clusters=5, random_state=0, init=cluster_centers).fit(concat_embeddings)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, verbose=1, perplexity=30, n_iter=3000)
tsne_results = tsne.fit_transform(concat_embeddings)

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(1, 1, 1, title='tSNE' )
# Create the scatter
ax.scatter(
    x=tsne_results[:, 0], 
    y=tsne_results[:, 1], 
    c=kmeans.labels_, 
    cmap=plt.cm.get_cmap('Paired'))
ax.legend()
# ax.relim()
# # update ax.viewLim using the new dataLim
# ax.autoscale_view()

# %%
dic = {}
for w, l in zip(words, kmeans.labels_):
    if dic.get(l):
        dic[l].append(w)
    else:
        dic[l] = [w]
dic

# %%
from sklearn.metrics.cluster import adjusted_rand_score

adjusted_rand_score(categories, kmeans.labels_)

# %%
def parse_input(filename):
    rows = []
    soup = BeautifulSoup(open(filename, "r"), "lxml")
    for r in soup.find_all('review'):
        restaurant_name = re.match(".*_(.*)_.*", r.get('rid')).groups()[0] #modify for visualizing
#         restaurant_name = r.get('rid') #modify for visualizing
        doc = ""
        aspect_words = []
        aspect_categories = []
        polarities = []
        for sentence in r.find_all('sentence'):
            sent = sentence.text.strip()
            doc += " " + sent
            for opinion in sentence.find_all('opinion'):
                aspect_words.append(opinion.get('target'))
                aspect_categories.append(opinion.get('category')[:opinion.get('category').index('#')])
                polarities.append(opinion.get('polarity'))
        rows.append((restaurant_name, doc, aspect_words, aspect_categories, polarities))
                                
    return  pd.DataFrame(rows, columns=['restaurant_name', 'text', 'aspect_words', 'aspect_categories', 'polarities'])

# %%
df = parse_input("./data/official_data/EN_REST_SB1_TEST.xml.gold")

# %%
df
# Out:
#                restaurant_name  \
# 0              BlueRibbonSushi
# 1              BlueRibbonSushi
# 2              SchoonerOrLater
# 3              SchoonerOrLater
# 4             PagodaRestaurant
# 5   ParkChaletGardenRestaurant
# 6                MiopostoCaffe
# 7                     Murphy's
# 8                   OpenSesame
# 9                         Sage
# 10             BlueRibbonSushi
# 11             BlueRibbonSushi
# 12             BlueRibbonSushi
# 13             BlueRibbonSushi
# 14          MercedesRestaurant
# 15          MercedesRestaurant
# 16             Patsy'sPizzeria
# 17             BlueRibbonSushi
# 18              Ray'sBoathouse
# 19             ProfessorThom's
# 20             ProfessorThom's
# 21             BlueRibbonSushi
# 22                      UvaBar
# 23                      UvaBar
# 24                India'sGrill
# 25                India'sGrill
# 26                India'sGrill
# 27          MercedesRestaurant
# 28                  OpenSesame
# 29          MercedesRestaurant
# ..                         ...
# 60              Ray'sBoathouse
# 61               MiopostoCaffe
# 62             SchoonerOrLater
# 63             SchoonerOrLater
# 64            PagodaRestaurant
# 65             BlueRibbonSushi
# 66  ParkChaletGardenRestaurant
# 67             BlueRibbonSushi
# 68             SchoonerOrLater
# 69             BlueRibbonSushi
# 70              Ray'sBoathouse
# 71            SnoozeanAMEatery
# 72             ProfessorThom's
# 73                         Bar
# 74             BlueRibbonSushi
# 75            SnoozeanAMEatery
# 76               MiopostoCaffe
# 77               MiopostoCaffe
# 78            SnoozeanAMEatery
# 79             BlueRibbonSushi
# 80            PagodaRestaurant
# 81            SnoozeanAMEatery
# 82                  OpenSesame
# 83             BlueRibbonSushi
# 84             Patsy'sPizzeria
# 85                      UvaBar
# 86                         Bar
# 87          MercedesRestaurant
# 88            SnoozeanAMEatery
# 89              Ray'sBoathouse
#
#                                                  text  \
# 0    Yum! Serves really good sushi. Not the bigges...
# 1    No Comparison – I can't say enough about this...
# 2    Snotty Attitude – We were treated very rudely...
# 3    Good food! – We love breakfast food. This is ...
# 4    Overrated – I was highly disappointed in the ...
# 5    Worst Service I Ever Had – A group of 5 of us...
# 6    Fabulous Italian Food! – I highly recommend M...
# 7    I love this restaurant – I will never forget ...
# 8    Mmm... good! – Went there last night with a f...
# 9    Finally a meal that you will remember for a l...
# 10   Very Disappointing – I took my parents here f...
# 11   I have eaten here three times and have found ...
# 12   Freshest sushi  – I love this restaurant. The...
# 13   Not recommanded!!! – The food was not great &...
# 14   great service – Pretty cheap for sit down Mex...
# 15   Ok.... – Maybe I went in on someone's bad day...
# 16   Mama Mia – I live in the neighborhood and fee...
# 17   Best Sushi in town. Have gone to all the top ...
# 18   The best calamari in Seattle! – ...and the be...
# 19   Endless fun, awesome music, great staff!!! – ...
# 20   I FOUND A NEW HOME ON SECOND AVENUE!!!!!!!!!!...
# 21   Go Beyond the California Rolls... The sushi h...
# 22   Mediocre food – We ate on the outside patio a...
# 23   Excellent food, nice ambience, fairly expensi...
# 24   Best Indian food in L.A. – I've been to over ...
# 25   hidden little jem – tucked away over by the B...
# 26   Nice food but no spice! – I really enjoyed my...
# 27   awesome find – I don't understand how I was a...
# 27  [NULL, fajita salad, colorado, fajitas, NULL, ...
# 28  [restaurant, decor, customer service, manager,...
# 29  [lunch spot, mexican spot, service, NULL, taco...
# ..                                                ...
# 60  [Crab Cakes, cakes, place, seasonal fish, seaf...
# 61  [Pizza, Service, pizza, mushroom pizza, caeser...
# 62    [Breakfast, breakfast, NULL, food, bloody mary]
# 63  [breakfast, crab eggs benedict, menu items, NU...
# 64  [chinese food, NULL, ambiance, NULL, staff, NU...
# 65  [portions, sushi, restaurant, sushi, sushi, NU...
# 66  [service, food, NULL, NULL, NULL, NULL, NULL, ...
# 67  [NULL, NULL, Spanish Mackeral special appetize...
# 68  [customer service, location along the marina i...
# 69       [sushi, fish, fish, service, sake selection]
# 70  [Dungeness crabs, seafood dinners, NULL, NULL,...
# 71  [Breakfast, drinks, corn beef hash, coffee, B ...
# 72  [Standby, NULL, spot, music, bar tenders, atmo...
# 73  [Food, Service, NULL, price fixed pre-show din...
# 74   [sake, food, sake, Server, lobster 3 ways, NULL]
# 75  [NULL, NULL, waiter, feel, bathroom stall, men...
# 76  [pizza joint, restaurant, NULL, pizza, salads,...
# 77  [NULL, Mioposto Café, pizza’s, menu, menu, piz...
# 78  [NULL, NULL, NULL, food, staff, atmosphere, pa...
# 79  [place, place, fish, chef special dinner, chef...
# 80   [NULL, atmosphere, honwy walnut prawns, service]
# 81    [NULL, service, coffee, food, NULL, NULL, NULL]
# 82  [NULL, restaurant, food, food, decor, music, a...
# 83  [NULL, place, NULL, menu, waiters, sushi, NULL...
# 84        [pepperoni, pepperoni's, pizza, NULL, NULL]
# 85  [Balcony, NULL, Food, Portions, menu selection...
# 86  [food, NULL, table, service, waiters, food, fi...
# 87  [place, service, NULL, chips  and salsa, NULL,...
# 88  [NULL, Service, Snooze, menu, Snooze, orange j...
# 89  [view, NULL, Ray's Boathouse, Sound views, vie...
#
#                                     aspect_categories  \
# 0                      [FOOD, FOOD, FOOD, FOOD, FOOD]
# 1   [RESTAURANT, RESTAURANT, FOOD, SERVICE, SERVIC...
# 2                         [SERVICE, SERVICE, SERVICE]
# 3          [FOOD, FOOD, SERVICE, SERVICE, FOOD, FOOD]
# 4   [RESTAURANT, FOOD, FOOD, FOOD, FOOD, AMBIENCE,...
# 5    [SERVICE, SERVICE, SERVICE, SERVICE, RESTAURANT]
# 6        [FOOD, RESTAURANT, RESTAURANT, DRINKS, FOOD]
# 7   [RESTAURANT, FOOD, SERVICE, AMBIENCE, RESTAURA...
# 8    [RESTAURANT, FOOD, FOOD, FOOD, FOOD, RESTAURANT]
# 9         [FOOD, FOOD, SERVICE, AMBIENCE, FOOD, FOOD]
# 10  [RESTAURANT, RESTAURANT, AMBIENCE, FOOD, FOOD,...
# 11  [FOOD, FOOD, SERVICE, RESTAURANT, FOOD, FOOD, ...
# 12  [FOOD, RESTAURANT, FOOD, FOOD, FOOD, FOOD, RES...
# 13            [RESTAURANT, FOOD, SERVICE, RESTAURANT]
# 82  [FOOD, RESTAURANT, FOOD, FOOD, AMBIENCE, AMBIE...
# 83  [FOOD, RESTAURANT, RESTAURANT, FOOD, SERVICE, ...
# 84         [FOOD, FOOD, FOOD, RESTAURANT, RESTAURANT]
# 85  [AMBIENCE, RESTAURANT, FOOD, FOOD, FOOD, FOOD,...
# 86  [FOOD, SERVICE, AMBIENCE, SERVICE, SERVICE, FO...
# 87  [RESTAURANT, SERVICE, FOOD, FOOD, RESTAURANT, ...
# 88  [RESTAURANT, SERVICE, AMBIENCE, FOOD, RESTAURA...
# 89  [LOCATION, RESTAURANT, RESTAURANT, LOCATION, L...
#
#                                            polarities
# 0   [positive, positive, neutral, positive, positive]
# 1   [positive, positive, positive, positive, posit...
# 2                      [negative, negative, negative]
# 3   [positive, positive, positive, positive, posit...
# 4   [negative, negative, negative, negative, negat...
# 5   [positive, negative, negative, negative, negat...
# 6   [positive, positive, positive, positive, posit...
# 7   [positive, positive, positive, positive, posit...
# 8   [positive, positive, positive, positive, posit...
# 9   [positive, positive, positive, positive, posit...
# 10  [negative, negative, positive, negative, negat...
# 11  [positive, positive, negative, negative, posit...
# 12  [positive, positive, positive, positive, posit...
# 13           [negative, negative, negative, negative]
# 14  [positive, positive, positive, positive, posit...
# 15  [negative, positive, positive, negative, negat...
# 16                     [positive, negative, positive]
# 17  [positive, positive, positive, positive, posit...
# 18           [positive, positive, positive, positive]
# 19  [positive, positive, positive, positive, posit...
# 20  [positive, positive, positive, positive, posit...
# 21  [positive, positive, positive, positive, posit...
# 22  [neutral, neutral, negative, negative, negativ...
# 23  [positive, positive, negative, positive, posit...
# 24  [positive, positive, positive, positive, posit...
# 25  [positive, neutral, positive, positive, positi...
# 26  [positive, negative, positive, positive, posit...
# 27  [positive, positive, positive, positive, posit...
# 28  [positive, positive, positive, positive, posit...
# 29  [positive, positive, positive, positive, posit...
# ..                                                ...
# 60  [positive, positive, positive, positive, posit...
# 61  [positive, negative, positive, positive, posit...
# 62  [positive, positive, positive, positive, posit...
# 63  [positive, positive, positive, positive, posit...
# 64  [positive, positive, positive, positive, posit...
# 65  [negative, positive, negative, negative, negat...
# 66  [negative, neutral, negative, negative, negati...
# 67  [positive, positive, positive, positive, posit...
# 68  [negative, positive, neutral, negative, positi...
# 69  [positive, positive, negative, positive, posit...
# 70  [positive, positive, positive, neutral, positi...
# 71  [positive, positive, positive, positive, posit...
# 72  [positive, positive, positive, positive, posit...
# 73  [positive, positive, neutral, neutral, positiv...
# 74  [positive, positive, positive, positive, posit...
# 75  [negative, neutral, negative, negative, negati...
# 76  [positive, positive, positive, positive, posit...
# 77  [positive, positive, positive, positive, posit...
# 78  [positive, negative, positive, positive, posit...
# 79  [negative, negative, negative, negative, negat...
# 80           [positive, positive, positive, positive]
# 81  [negative, positive, positive, positive, posit...
# 82  [positive, positive, positive, positive, posit...
# 83  [positive, neutral, positive, positive, positi...
# 84  [positive, positive, positive, negative, negat...
# 85  [positive, neutral, positive, neutral, neutral...
# 86  [positive, positive, positive, positive, posit...
# 87  [positive, positive, positive, positive, posit...
# 88  [negative, neutral, positive, negative, negati...
# 89  [positive, positive, positive, positive, posit...
#
# [90 rows x 5 columns]

# %%
#TODO: replace split with tokenize

def get_embeddings(words, glove_model, domain_model, use_fastText=False):
    punctuation_string = "".join(string.punctuation)
    embeddings = []
    dom_embeddings = []
    
    #let us handle OOV words.
    oov_model = None
    if use_fastText:
        oov_words = []
        for w in words:
            try:
                emb = domain_model.loc[w.strip(punctuation_string)]
            except:
                oov_words.append(t)
        oov_words = set(oov_words)
        
        with open("./oov_words.txt", "w") as file:
            for w in oov_words:
                file.write(w + "\n")
        
        start_time = timeit.default_timer()
        
        bashCommand = "./fastText-0.2.0/fasttext print-word-vectors ./data/embedding/restaurant_emb.vec.bin < ./oov_words.txt > ./oov.vec"
        os.system(bashCommand)
        
        elapsed = timeit.default_timer() - start_time
        print("Word vectors written, it took " + str(elapsed) + " seconds")
        oov_model = pd.read_csv("./oov.vec", sep=" ", header=None, index_col=0, skiprows=1)
        oov_model = oov_model.drop(labels=101, axis=1)
    
    for w in targets:
        emb = w2v(w.strip(punctuation_string), glove_model, 300)
        dom_emb = w2v(w.strip(punctuation_string), domain_model, 100, oov_model)
        embeddings.append(emb)
        dom_embeddings.append(dom_emb)
        words.append(t)      
        i+=1
        print(str(i) + str(emb.shape) + " " + str(dom_emb.shape))
    
    
    #normalize:
    embeddings = [e/np.linalg.norm(e) if np.linalg.norm(e) != 0 else e for e in embeddings]
    dom_embeddings = [e/np.linalg.norm(e) if np.linalg.norm(e) != 0 else e for e in dom_embeddings]
    
    return [np.hstack((ge,de)) for ge,de in zip(embeddings, dom_embeddings)]

# %%
@interact
def visualize_restaurant(x=df.restaurant_name.unique()):
    return df.loc[df['restaurant_name'] == x]
    
    #replace with model
    aspect_words = set(df.loc[df['restaurant_name'] == x]['aspect_words'].to_list())
    
    #get dual embeddings
    embeddings = get_embeddings(aspect_words)
    
    #cluster
    kmeans = KMeans(n_clusters=5, random_state=0).fit(concat_embeddings)
    
    #find sentiment of each cluster and plot
    
    
    #tsne plot of the embeddings
    tsne = TSNE(n_components=2, verbose=1, perplexity=30, n_iter=3000)
    tsne_results = tsne.fit_transform(concat_embeddings)
# Out:
# interactive(children=(Dropdown(description='x', options=('BlueRibbonSushi', 'SchoonerOrLater', 'PagodaRestaura…

# %%
nlp = spacy.load('en')

# %%
doc = nlp(df.iloc[0].text)
for token in doc:
    if token.dep_ == ""
    print(str(token) + " | " + str(token.dep_))
# Out:
#   |
# Yum | ROOT
# ! | punct
# Serves | nmod
# really | advmod
# good | amod
# sushi | ROOT
# . | punct
# Not | neg
# the | det
# biggest | amod
# portions | ROOT
# but | cc
# adequate | conj
# . | punct
# Green | compound
# Tea | compound
# creme | nsubj
# brulee | appos
# is | ROOT
# a | det
# must | attr
# ! | punct
# Do | aux
# n't | neg
# leave | ROOT
# the | det
# restaurant | dobj
# without | prep
# it | pobj
# . | punct
